# %% [markdown]
# # Coursera Certificate for Algorithmic Toolbox - University of California San Diego - HSE Moscow (National Research University Higher School of Economics)

# %% [markdown]
# ## LinkedIn

# %% [markdown]
# [https://www.linkedin.com/in/jorge-aurelio-morales-manrique-3117471b5/](https://www.linkedin.com/in/jorge-aurelio-morales-manrique-3117471b5/)

# %% [markdown]
# ## Screenshots

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)
